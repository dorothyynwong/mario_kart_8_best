# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

data_dir = Path("../input/mario-kart-8-deluxe-ingame-statistics")
data_dir_output = Path("./")
df_karts = pd.read_csv(data_dir / "bodies_karts.csv",delimiter=";")
df_drivers = pd.read_csv(data_dir / "drivers.csv",delimiter=";")
df_gliders = pd.read_csv(data_dir / "gliders.csv",delimiter=";")
df_tires = pd.read_csv(data_dir / "tires.csv",delimiter=";")

output_best = "best_combination.csv"
output_combined = "kart_combination.csv"

# %%
df_karts.head()
# Out:
#             Body  Weight  Acceleration  On-Road traction  Off-Road Traction  \
# 0  Standard Kart       2             4                 3                  3
# 1     Pipe Frame       1             6                 3                  4
# 2         Mach 8       3             3                 2                  4
# 3   Steel Driver       4             1                 1                  3
# 4    Cat Cruiser       2             5                 4                  3
#
#    Mini-Turbo  Ground Speed  Water Speed  Anti-Gravity Speed  Air Speed  \
# 0           4             3            3                   3          3
# 1           6             1            3                   1          1
# 2           4             3            3                   5          4
# 3           2             4            5                   2          0
# 4           5             2            2                   3          4
#
#    Ground Handling  Water Handling  Anti-Gravity Handling  Air Handling
# ...

# %%
df_drivers.head()
# Out:
#   Driver  Weight  Acceleration  On-Road traction  Off-Road Traction  \
# 0  Mario       6             2                 4                  2
# 1  Luigi       6             2                 5                  1
# 2  Peach       4             3                 3                  3
# 3  Daisy       4             3                 3                  3
# 4  Yoshi       4             3                 3                  3
#
#    Mini-Turbo  Ground Speed  Water Speed  Anti-Gravity Speed  Air Speed  \
# 0           2             6            6                   6          6
# 1           2             6            6                   6          6
# 2           3             5            5                   5          5
# 3           3             5            5                   5          5
# 4           3             5            5                   5          5
#
#    Ground Handling  Water Handling  Anti-Gravity Handling  Air Handling
# ...

# %%
df_gliders.head()
# Out:
#           Glider  Weight  Acceleration  On-Road traction  Off-Road Traction  \
# 0   Super Glider       1             1                 1                  1
# 1   Cloud Glider       0             2                 1                  1
# 2    Wario Wing        2             1                 2                  0
# 3    Waddle Wing       1             1                 1                  1
# 4  Peach Parasol       1             2                 2                  0
#
#    Mini-Turbo  Ground Speed  Water Speed  Anti-Gravity Speed  Air Speed  \
# 0           1             1            1                   0          2
# 1           2             0            1                   1          1
# 2           1             1            0                   1          2
# 3           1             1            1                   0          2
# 4           2             0            0                   1          1
#
#    Ground Handling  Water Handling  Anti-Gravity Handling  Air Handling
# ...

# %%
df_tires.head()
# Out:
#        Tire  Weight  Acceleration  On-Road traction  Off-Road Traction  \
# 0  Standard       2             4                 2                  5
# 1   Monster       4             2                 3                  7
# 2    Roller       0             6                 0                  4
# 3      Slim       2             2                 4                  1
# 4     Slick       3             1                 4                  0
#
#    Mini-Turbo  Ground Speed  Water Speed  Anti-Gravity Speed  Air Speed  \
# 0           3             2            3                   2          3
# 1           2             2            2                   2          1
# 2           6             0            3                   0          3
# 3           2             3            2                   4          2
# 4           0             4            0                   4          0
#
#    Ground Handling  Water Handling  Anti-Gravity Handling  Air Handling
# ...

# %%
df_karts.shape
# Out:
# (40, 14)

# %%
df_drivers.shape
# Out:
# (43, 14)

# %%
df_gliders.shape
# Out:
# (14, 14)

# %%
df_tires.shape
# Out:
# (21, 14)

# %%
features = ['Weight','Acceleration','On-Road traction','Off-Road Traction','Mini-Turbo',
            'Ground Speed','Water Speed','Anti-Gravity Speed','Air Speed','Ground Handling',
            'Water Handling','Anti-Gravity Handling','Air Handling'
           ]

# %%
df_karts.sort_values(by=features, ignore_index=True)
# Out:
#                  Body  Weight  Acceleration  On-Road traction  \
# 0         Blue Falcon       0             3                 1
# 1         Splat Buggy       0             3                 1
# 2            Landship       0             6                 0
# 3            Streetle       0             6                 0
# 4          Biddybuggy       0             7                 1
# 5          Mr. Scooty       0             7                 1
# 6             Prancer       1             2                 1
# 7          Sport Bike       1             2                 1
# 8            Jet Bike       1             2                 1
# 9       Standard Bike       1             5                 3
# 10        Flame Rider       1             5                 3
# 11       Wild Wiggler       1             5                 3
# 12  W 25 Silver Arrow       1             5                 3
# 13         Pipe Frame       1             6                 3
# ...

# %%
grouped_karts = ['Falcon-Buggy','Landship-Streetle','Buggy-Scooty','Prancer-Bikes','Bike-Flame-Wiggler-Arrow',
                'Frame-Varmint-Tripper','Sneeker-Gold-Master','Standard-Duke-Roadster',
                 'Cat-Comet-Yoshi-Teddy','Circuit-Dasher-Wing',
                 'Tanooki-Koopa','March-Coupe-Inkstriker','Badwagon-ATV-GLA','Steel-Tri-Bone'
                ]

# %%
karts = df_karts.copy()
karts.drop_duplicates(features,inplace=True)
unique_karts = karts.sort_values(features)
karts = unique_karts.reset_index(drop=True)
karts['Body'] = grouped_karts
karts
# Out:
#                         Body  Weight  Acceleration  On-Road traction  \
# 0               Falcon-Buggy       0             3                 1
# 1          Landship-Streetle       0             6                 0
# 2               Buggy-Scooty       0             7                 1
# 3              Prancer-Bikes       1             2                 1
# 4   Bike-Flame-Wiggler-Arrow       1             5                 3
# 5      Frame-Varmint-Tripper       1             6                 3
# 6        Sneeker-Gold-Master       2             2                 1
# 7     Standard-Duke-Roadster       2             4                 3
# 8      Cat-Comet-Yoshi-Teddy       2             5                 4
# 9        Circuit-Dasher-Wing       3             1                 3
# 10             Tanooki-Koopa       3             2                 4
# 11    March-Coupe-Inkstriker       3             3                 2
# 12          Badwagon-ATV-GLA       4             0                 2
# ...

# %%
df_drivers.sort_values(features)
# Out:
#                Driver  Weight  Acceleration  On-Road traction  \
# 19         Baby Peach       0             4                 3
# 20         Baby Daisy       0             4                 3
# 21      Baby Rosalina       0             5                 4
# 23              Lemmy       0             5                 4
# 17         Baby Mario       1             5                 2
# 18         Baby Luigi       1             5                 2
# 38          Dry Bones       1             5                 2
# 7        Koopa Troopa       2             4                 1
# 15             Lakitu       2             4                 1
# 39         Bowser Jr.       2             4                 1
# 6            Toadette       2             5                 4
# 24              Wendy       2             5                 4
# 33           Isabelle       2             5                 4
# 34          Cat Peach       3             4                 2
# ...

# %%
grouped_drivers = ['BabyPrincesses', 'BabyRosa-Lemmy', 'BabyMario-Luigi-Bones',
                  'Koopa-Lakitu-Bowser', 'Toadette-Wendy-Isabelle',
                  'CatPeach-VillagerF-InklingG', 'Toad-Shy-Larry',
                  'Peach-Daisy-Yoshi', 'Tanooki-VillagerM-InklingB',
                  'Mario-Ludwig-MiiM', 'Luigi-Iggy', 'Rosa-Link-Boo',
                  'Donkey-Waluigi-Roy', 'Wario-DryBowser', 'Boswer-Morton',
                  'Metal-Golds']

# %%
drivers = df_drivers.copy()
drivers.drop_duplicates(features,inplace=True)
unique_drivers = drivers.sort_values(features)
drivers = unique_drivers.reset_index(drop=True)
drivers['Driver'] = grouped_drivers
drivers
# Out:
#                          Driver  Weight  Acceleration  On-Road traction  \
# 0                BabyPrincesses       0             4                 3
# 1                BabyRosa-Lemmy       0             5                 4
# 2         BabyMario-Luigi-Bones       1             5                 2
# 3           Koopa-Lakitu-Bowser       2             4                 1
# 4       Toadette-Wendy-Isabelle       2             5                 4
# 5   CatPeach-VillagerF-InklingG       3             4                 2
# 6                Toad-Shy-Larry       3             4                 3
# 7             Peach-Daisy-Yoshi       4             3                 3
# 8    Tanooki-VillagerM-InklingB       5             3                 7
# 9             Mario-Ludwig-MiiM       6             2                 4
# 10                   Luigi-Iggy       6             2                 5
# 11                Rosa-Link-Boo       7             1                 9
# ...

# %%
df_gliders.sort_values(features)
# Out:
#              Glider  Weight  Acceleration  On-Road traction  \
# 1      Cloud Glider       0             2                 1
# 5         Parachute       0             2                 1
# 7   Flower Glider         0             2                 1
# 13     Paper Glider       0             2                 1
# 0      Super Glider       1             1                 1
# 3       Waddle Wing       1             1                 1
# 12      Hylian Kite       1             1                 1
# 4     Peach Parasol       1             2                 2
# 6          Parafoil       1             2                 2
# 8       Bowser Kite       1             2                 2
# 10    MKTV Parafoil       1             2                 2
# 2       Wario Wing        2             1                 2
# 9    Plane Glider         2             1                 2
# 11      Gold Glider       2             1                 2
#
# ...

# %%
grouped_gliders = ['Cloud-Parachute-Flower-Paper', 'Super-Waddle-Hylian',
                   'Peach-Parafoil-Bowser-MKTV', 'Wario-Plane-Gold']

# %%
gliders = df_gliders.copy()
gliders.drop_duplicates(features,inplace=True)
unique_gliders = gliders.sort_values(features)
gliders = unique_gliders.reset_index(drop=True)
gliders['Glider'] = grouped_gliders
gliders
# Out:
#                          Glider  Weight  Acceleration  On-Road traction  \
# 0  Cloud-Parachute-Flower-Paper       0             2                 1
# 1           Super-Waddle-Hylian       1             1                 1
# 2    Peach-Parafoil-Bowser-MKTV       1             2                 2
# 3              Wario-Plane-Gold       2             1                 2
#
#    Off-Road Traction  Mini-Turbo  Ground Speed  Water Speed  \
# 0                  1           2             0            1
# 1                  1           1             1            1
# 2                  0           2             0            0
# 3                  0           1             1            0
#
#    Anti-Gravity Speed  Air Speed  Ground Handling  Water Handling  \
# 0                   1          1                1               0
# 1                   0          2                1               0
# 2                   1          1                1               1
# ...

# %%
df_tires.sort_values(features)
# Out:
#               Tire  Weight  Acceleration  On-Road traction  Off-Road Traction  \
# 6           Button       0             5                 1                  3
# 20      Leaf Tires       0             5                 1                  3
# 2           Roller       0             6                 0                  4
# 13    Azure Roller       0             6                 0                  4
# 8           Sponge       1             4                 2                  6
# 10         Cushion       1             4                 2                  6
# 3             Slim       2             2                 4                  1
# 9             Wood       2             2                 4                  1
# 14    Crimson Slim       2             2                 4                  1
# 0         Standard       2             4                 2                  5
# 11   Blue Standard       2             4                 2                  5
# ...

# %%
grouped_tires = ['Button-Leaf', 'Roller-Azure', 'Sponge-Cushion', 'Slim-Wood-Crimson',
                 'Standards-GLA', 'Slicks', 'OffRoads-Triforce', 'Metal-Gold', 'Monsters']

# %%
tires = df_tires.copy()
tires.drop_duplicates(features,inplace=True)
unique_tires = tires.sort_values(features)
tires = unique_tires.reset_index(drop=True)
tires['Tire'] = grouped_tires
tires
# Out:
#                 Tire  Weight  Acceleration  On-Road traction  \
# 0        Button-Leaf       0             5                 1
# 1       Roller-Azure       0             6                 0
# 2     Sponge-Cushion       1             4                 2
# 3  Slim-Wood-Crimson       2             2                 4
# 4      Standards-GLA       2             4                 2
# 5             Slicks       3             1                 4
# 6  OffRoads-Triforce       3             3                 3
# 7         Metal-Gold       4             0                 1
# 8           Monsters       4             2                 3
#
#    Off-Road Traction  Mini-Turbo  Ground Speed  Water Speed  \
# 0                  3           5             1            2
# 1                  4           6             0            3
# 2                  6           4             1            1
# 3                  1           2             3            2
# ...

# %%
parts = ['Driver','Body','Glider','Tire']
df_combined = pd.DataFrame(columns = parts + features)
df_combined['Overall'] = 0
df_combined['Near Avg Cnt'] = 0
i = 0
for index, driver in drivers.iterrows():
    driver_name = driver['Driver']   
    tmp = driver[features]
    for index2, kart in karts.iterrows():
        kart_name = kart['Body']
        for col in features:
            tmp[col] = tmp[col] + kart[col]
        for index3, glider in gliders.iterrows():
            glider_name = glider['Glider']
            for col in features:
                tmp[col] = tmp[col] + glider[col]
            for index4, tire in tires.iterrows():   
                tire_name = tire['Tire']
                tmp[col] = tmp[col] + tire[col]
                df_combined.loc[i, parts]= [driver_name, kart_name, glider_name, tire_name]
                df_combined.loc[i, features] = tmp
                df_combined.loc[i, 'Overall'] = tmp.sum()
                df_combined.loc[i, 'Near Avg Cnt'] = 0
                i = i+1
df_combined.tail()
# Out:
#            Driver            Body            Glider               Tire Weight  \
# 8059  Metal-Golds  Steel-Tri-Bone  Wario-Plane-Gold      Standards-GLA     92
# 8060  Metal-Golds  Steel-Tri-Bone  Wario-Plane-Gold             Slicks     92
# 8061  Metal-Golds  Steel-Tri-Bone  Wario-Plane-Gold  OffRoads-Triforce     92
# 8062  Metal-Golds  Steel-Tri-Bone  Wario-Plane-Gold         Metal-Gold     92
# 8063  Metal-Golds  Steel-Tri-Bone  Wario-Plane-Gold           Monsters     92
#
#      Acceleration On-Road traction Off-Road Traction Mini-Turbo Ground Speed  \
# 8059          132              121                79        137           76
# 8060          132              121                79        137           76
# 8061          132              121                79        137           76
# 8062          132              121                79        137           76
# 8063          132              121                79        137           76
#
# ...

# %% [markdown]
# ### Combination with the best overall scores

# %%
df_best = pd.DataFrame()
df_best_tmp = df_combined[df_combined['Overall']==df_combined['Overall'].max()]
df_best_tmp['Feature'] = "Overall"
df_best = df_best.append(df_best_tmp)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for feature in features:
    df_best_tmp = df_combined[df_combined[feature]==df_combined[feature].max()]
    df_best_tmp['Feature'] = feature
    df_best = df_best.append(df_best_tmp)
    
df_best
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#               Driver            Body            Glider               Tire  \
# 8063     Metal-Golds  Steel-Tri-Bone  Wario-Plane-Gold           Monsters
# 7551   Boswer-Morton  Steel-Tri-Bone  Wario-Plane-Gold        Button-Leaf
# 7552   Boswer-Morton  Steel-Tri-Bone  Wario-Plane-Gold       Roller-Azure
# 7553   Boswer-Morton  Steel-Tri-Bone  Wario-Plane-Gold     Sponge-Cushion
# 7554   Boswer-Morton  Steel-Tri-Bone  Wario-Plane-Gold  Slim-Wood-Crimson
# ...              ...             ...               ...                ...
# ...

# %%
average_dict = {}
for feature in features:
  average_dict[feature] = df_combined[feature].mean(axis=0)

average_dict
# Out:
# {'Weight': 41.07142857142857,
#  'Acceleration': 76.25,
#  'On-Road traction': 60.5,
#  'Off-Road Traction': 43.767857142857146,
#  'Mini-Turbo': 78.05357142857143,
#  'Ground Speed': 37.660714285714285,
#  'Water Speed': 39.125,
#  'Anti-Gravity Speed': 46.125,
#  'Air Speed': 65.73214285714286,
#  'Ground Handling': 59.044642857142854,
#  'Water Handling': 42.50892857142857,
#  'Anti-Gravity Handling': 45.223214285714285,
#  'Air Handling': 630.3462301587301}

# %%
#Count number of features most near average
for feature in features:
  df_combined.loc[(df_combined[feature]<=average_dict[feature]*1.05) & (df_combined[feature]>=average_dict[feature]*0.95),'Near Avg Cnt'] += 1

# %%
df_avg_tmp = df_combined[df_combined['Near Avg Cnt']==df_combined['Near Avg Cnt'].max()]
df_avg_tmp['Feature'] = "Average"
df_best = df_best.append(df_avg_tmp)
df_best
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              Driver                 Body            Glider               Tire  \
# 8063    Metal-Golds       Steel-Tri-Bone  Wario-Plane-Gold           Monsters
# 7551  Boswer-Morton       Steel-Tri-Bone  Wario-Plane-Gold        Button-Leaf
# 7552  Boswer-Morton       Steel-Tri-Bone  Wario-Plane-Gold       Roller-Azure
# 7553  Boswer-Morton       Steel-Tri-Bone  Wario-Plane-Gold     Sponge-Cushion
# 7554  Boswer-Morton       Steel-Tri-Bone  Wario-Plane-Gold  Slim-Wood-Crimson
# ...             ...                  ...               ...                ...
# ...

# %%
df_best.to_csv(data_dir_output / output_best)
df_combined.to_csv(data_dir_output / output_combined)
